# %% [markdown]
# <a href="https://colab.research.google.com/github/yash2799/coursera-test/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-825ba34f-de22-4779-b953-8f0316d80494" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-825ba34f-de22-4779-b953-8f0316d80494">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dataset.xlsx to dataset (2).xlsx

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
import sklearn

# %%
df = pd.read_excel("dataset.xlsx")

from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns
sns.set()

# %%
df
# Out:
#              SourceIP  ...      Label
# 0      192.168.20.205  ...  Malicious
# 1             8.8.4.4  ...  Malicious
# 2             8.8.4.4  ...  Malicious
# 3             8.8.4.4  ...  Malicious
# 4             8.8.4.4  ...  Malicious
# ...               ...  ...        ...
# 10422  104.27.173.205  ...     NonDoH
# 10423  192.168.20.191  ...     NonDoH
# 10424  192.168.20.191  ...     NonDoH
# 10425  192.168.20.191  ...     NonDoH
# 10426  192.168.20.191  ...     NonDoH
#
# [10427 rows x 34 columns]

# %%
df=df.dropna()

# %%
X=df.values[:,:-1]
X.shape
df.info()

df.head
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10397 entries, 0 to 10426
# Data columns (total 32 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   SourcePort                              10397 non-null  int32
#  1   DestinationPort                         10397 non-null  int32
#  2   Duration                                10397 non-null  int32
#  3   FlowBytesSent                           10397 non-null  int32
#  4   FlowSentRate                            10397 non-null  int32
#  5   FlowBytesReceived                       10397 non-null  int32
#  6   FlowReceivedRate                        10397 non-null  int32
#  7   PacketLengthVariance                    10397 non-null  int32
#  8   PacketLengthStandardDeviation           10397 non-null  int32
#  9   PacketLengthMean                        10397 non-null  int32
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Label'] = le.fit_transform(df['Label'])
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10397 entries, 0 to 10426
# Data columns (total 32 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   SourcePort                              10397 non-null  int32
#  1   DestinationPort                         10397 non-null  int32
#  2   Duration                                10397 non-null  int32
#  3   FlowBytesSent                           10397 non-null  int32
#  4   FlowSentRate                            10397 non-null  int32
#  5   FlowBytesReceived                       10397 non-null  int32
#  6   FlowReceivedRate                        10397 non-null  int32
#  7   PacketLengthVariance                    10397 non-null  int32
#  8   PacketLengthStandardDeviation           10397 non-null  int32
#  9   PacketLengthMean                        10397 non-null  int32
# ...

# %%
Y=df.values[:,4]
Y
# Out:
# array([ 384, 3919, 6223, ..., 2193,   14, 2186])

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20)
X_train.shape
# Out:
# (8317, 31)

# %%
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
Y_pred=neigh.predict(X_test)
Y_pred
# Out:
# array([  54,   99,  239, ...,   53, 1636,  187])

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
print("Accuracy:", accuracy_score(Y_test,Y_pred)*100)
print("Report:", classification_report(Y_test,Y_pred))
pd.f1_score(Y_test, Y_pred, average='weighted')
# Out:
# Accuracy: 24.03846153846154
# Report:               precision    recall  f1-score   support
#
#            1       1.00      0.57      0.73         7
#            2       0.00      0.00      0.00         0
#            3       0.96      0.96      0.96        75
#            4       0.87      0.95      0.91        84
#            5       0.92      0.76      0.83        45
#            6       0.00      0.00      0.00         1
#            7       0.72      0.88      0.79        32
#            8       0.67      0.40      0.50         5
#            9       0.36      0.50      0.42         8
#           10       0.31      0.50      0.38         8
#           11       0.60      0.38      0.46         8
#           12       0.00      0.00      0.00         1
#           14       1.00      0.67      0.80         6
#           18       0.00      0.00      0.00         1
#           19       1.00      1.00      1.00         1
#           25       0.00      0.00      0.00         0
# ...
